# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
pixel_height_width = 24
random_seed = 100

dataset_row = 650
dataset_col = np.square(pixel_height_width)
category_num = 5

train_data_len = 600
test_data_len = 50

# %%
dataset = np.zeros((category_num,dataset_row,dataset_col))
# dataset[0] = np.genfromtxt("dataset\\none.txt", delimiter=",", dtype=int)[0:dataset_row]
# dataset[1] = np.genfromtxt("dataset\\open.txt", delimiter=",", dtype=int)[0:dataset_row]
# dataset[2] = np.genfromtxt("dataset\\close.txt", delimiter=",", dtype=int)[0:dataset_row]
# dataset[3] = np.genfromtxt("dataset\\cross.txt", delimiter=",", dtype=int)[0:dataset_row]
# dataset[4] = np.genfromtxt("dataset\\close_near.txt", delimiter=",", dtype=int)[0:dataset_row]

dataset[0] = np.genfromtxt("dataset\\none.log", delimiter=",", dtype='float32',encoding='utf-8')[1:dataset_row+1]
dataset[1] = np.genfromtxt("dataset\\1.log", delimiter=",", dtype='float32',encoding='utf-8')[1:dataset_row+1]
dataset[2] = np.genfromtxt("dataset\\2.log", delimiter=",", dtype='float32',encoding='utf-8')[1:dataset_row+1]
dataset[3] = np.genfromtxt("dataset\\3.log", delimiter=",", dtype='float32',encoding='utf-8')[1:dataset_row+1]

# %%
np.random.seed(random_seed)
for i in range(category_num):
    np.random.shuffle(dataset[i])

# %%
train_data = np.zeros((category_num,train_data_len,dataset_col))
test_data = np.zeros((category_num,test_data_len,dataset_col))

for i in range(category_num):
    train_data[i] = dataset[i][0:train_data_len]
    test_data[i] = dataset[i][train_data_len:train_data_len+test_data_len]
test_data.shape
# Out:
# (5, 50, 576)

# %%
graph = train_data[1][200].reshape(24, 24)
plt.imshow(graph, cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %%
for i in range(category_num):
    train_data[i] -= np.average(train_data[i],axis = 1).reshape(-1,1)
    test_data[i] -= np.average(test_data[i],axis = 1).reshape(-1,1)
train_data /= 10
test_data /= 10

train_data.shape
# Out:
# (5, 600, 576)

# %%
graph = train_data[3][200].reshape(24, 24)
plt.imshow(graph, cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %%
train_data = train_data.reshape(-1,dataset_col)
train_data = train_data.reshape(train_data.shape[0],24,24,1)

test_data = test_data.reshape(-1,dataset_col)
test_data = test_data.reshape(test_data.shape[0],24,24,1)

train_data.shape,test_data.shape
# Out:
# ((3000, 24, 24, 1), (250, 24, 24, 1))

# %%
train_label = np.zeros(train_data.shape[0])
test_label = np.zeros(test_data.shape[0])

base = 0
for i in range(category_num):
    train_label[base:base+train_data_len] = i
    base += train_data_len
    
base = 0
for i in range(category_num):
    test_label[base:base+test_data_len] = i
    base += test_data_len

train_label = to_categorical(train_label)
test_label = to_categorical(test_label)

# %%
network = Sequential()
network.add(Conv2D(5, (3,3),input_shape=(pixel_height_width, pixel_height_width,1),activation='relu'))
network.add(MaxPooling2D(pool_size=(2,2),padding='valid'))
network.add(Flatten())
network.add(Dense(128, activation='relu'))
network.add(Dense(64, activation='relu'))
network.add(Dense(category_num, activation='softmax'))
network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

network.fit(train_data, train_label, validation_split = 0.1, epochs=5, batch_size=10)
network.save("esp-gesture.h5")

test_loss, test_acc = network.evaluate(test_data, test_label)
print("test_loss:", test_loss)
print("test_acc:", test_acc)
# Out:
# Epoch 1/10
# 270/270 [==============================] - 2s 4ms/step - loss: 0.2788 - categorical_accuracy: 0.9064 - val_loss: 5.7219e-05 - val_categorical_accuracy: 1.0000
# Epoch 2/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0049 - categorical_accuracy: 0.9982 - val_loss: 1.1921e-06 - val_categorical_accuracy: 1.0000
# Epoch 3/10
# 270/270 [==============================] - 1s 3ms/step - loss: 8.9775e-04 - categorical_accuracy: 0.9998 - val_loss: 1.1921e-07 - val_categorical_accuracy: 1.0000
# Epoch 4/10
# 270/270 [==============================] - 1s 3ms/step - loss: 1.0622e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/10
# 270/270 [==============================] - 1s 3ms/step - loss: 3.3300e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/10
# 270/270 [==============================] - 1s 3ms/step - loss: 1.3731e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/10
# 270/270 [==============================] - 1s 3ms/step - loss: 1.5090e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/10
# 270/270 [==============================] - 1s 3ms/step - loss: 1.1106e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/10
# 270/270 [==============================] - 1s 3ms/step - loss: 1.6756e-11 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# test_loss: 0.0
# test_acc: 1.0

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(network)
tflite_model = converter.convert()
# Save the model to disk
open("model.tflite", "wb").write(tflite_model)




# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(network)
# Indicate that we want to perform the default optimizations,
# which includes quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]


# Define a generator function that provides our test data's x values
# as a representative dataset, and tell the converter to use it
def representative_dataset_generator():
    for value in test_data:
    # Each scalar value must be inside of a 2D array that is wrapped in a list
        yield [np.array(value, dtype=np.float32, ndmin=4)]


converter.representative_dataset = representative_dataset_generator
# Convert the model
tflite_model = converter.convert()
open("model_quantized.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ADMINI~1\AppData\Local\Temp\tmpfe82fsx6\assets
# INFO:tensorflow:Assets written to: C:\Users\ADMINI~1\AppData\Local\Temp\tmpfe82fsx6\assets
# INFO:tensorflow:Assets written to: C:\Users\ADMINI~1\AppData\Local\Temp\tmpnb_vbg3c\assets
# INFO:tensorflow:Assets written to: C:\Users\ADMINI~1\AppData\Local\Temp\tmpnb_vbg3c\assets
# 91152
